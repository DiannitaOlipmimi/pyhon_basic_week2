# %% [markdown]
# ## 6.1. INTODUCTION: SEQUENCES
# ---
#
# mempelajari operator-operator yang dapat digunakan dalam *sequences* beserta beberapa *function* dan perbedaan dari list dan strings
#
# ---
# ### 6.1.1 Learing Goals
# - To understand different operations that can be performed on strings, lists, and tuples
# - To distinguish between different uses of [] in Python
# ---
# ### 6.1.2 Tujuan
# - Predict the output of split and join operations
# - Read and write expressions that use slices
# - Read and write expressions that use concatenation and repetition

# %% [markdown]
# ## 6.2. Strings dan List
# ---
# Strings merupakan kumpulan karakter yang berurutan dari kiri ke kanan. strings tanpa karakter disebut dengan *empty string* dan biasa diwakili degan '' atau "". sedangkan List adalah kumpulan nilai berurutan yang dapat memiliki macam-macam tipe data (tidak hanya strings), dimana setiap nilainya diidentifikasi dengan index dan nilainya disebut elemen.
